# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
import numpy as np
import pandas as pd
from pprint import pprint
from os import listdir
from os.path import isfile, join
from sklearn.model_selection import StratifiedKFold
from scipy import stats
import numpy as np
from sklearn import linear_model, svm
import re
from sklearn.metrics import roc_curve, auc,f1_score
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import os          
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import roc_curve, auc,f1_score
import sklearn.linear_model as lm



print("finished this block")
# Out:
# finished this block

# %%
import sys, os
sys.path.insert(0, '..')
from lib import models, graph, coarsening, utils
import tensorflow as tf
import time
from sklearn.model_selection import train_test_split
from sklearn.model_selection import LeaveOneOut
from scipy import stats
import matplotlib.pyplot as plt

# %matplotlib inline
flags = tf.app.flags
FLAGS = flags.FLAGS
print("finished this block")
# Out:
# /anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# finished this block

# %%
os.getcwd()
os.chdir('../braindata')
dd =pd.read_csv("data_3_all.csv",header=0)
import csv
with open('data_3_all.csv', 'r') as f:
    d_reader = csv.DictReader(f)
    headers = d_reader.fieldnames
print("finished this block")
# Out:
# finished this block

# %%
data=np.array(dd)
idx_IN_columns = np.append(np.array([3,4]),np.array(range(11,data.shape[1])))
X=data[:,idx_IN_columns]
X = stats.zscore(X)
y=data[:,6]

ind_num=np.isnan(y)
# print(ind_num.shape)
y_no_nan = y[~ind_num]
X_no_nan = X[~ind_num,:]

y=y_no_nan
X=X_no_nan
np.isnan(X).any()
X[np.isnan(X)] = np.median(X[~np.isnan(X)])
print("finished this block")
# Out:
# finished this block
# /anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:2248: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd

# %%
feature_num_all=[]
GCN_all_feature=[]
GCN_f1s_feature=[]
base_labels= []

###########################
#From Yun's code, selecting the import features
clf = ExtraTreesClassifier(n_estimators=50,random_state=0)
clf = clf.fit(X, y)
importances = clf.feature_importances_
importances
indices = np.argsort(importances)[::-1]
############################
n_features = [100,1000]
n_features.sort()


print("Finished this block")
# Out:
# Finished this block

# %%
C = max(y) + 1  # number of classes    

common = {}
common['dir_name']       = 'Chenxiao_Testing'
common['num_epochs']     = 15
common['batch_size']     = 10
common['eval_frequency'] = common['num_epochs']
common['brelu']          = 'b1relu'
common['pool']           = 'mpool1'
common['filter']         = 'chebyshev5'

# Architecture.
common['F']              = [64, 64, 32]  # Number of graph convolutional filters.
common['K']              = [20, 20, 20]  # Polynomial orders.
common['p']              = [4, 4, 2]    # Pooling sizes.
common['M']              = [512, C]  # Output dimensionality of fully connected layers.

# Optimization.
common['regularization'] = 5e-4
common['dropout']        = 0.9
common['learning_rate']  = 1e-3
common['decay_rate']     = 0.95
common['momentum']       = 0.9
#params['decay_steps']    = n_train / params['batch_size']

model_perf = utils.model_perf()    

sep = '*' * 100
print("finished this block")
# Out:
# finished this block

# %%
###########################
#From Yun's code, selecting the import features
clf = ExtraTreesClassifier(n_estimators=50,random_state=0)
clf = clf.fit(X, y)
importances = clf.feature_importances_
importances
indices = np.argsort(importances)[::-1]
############################


number_of_features=1000
index=indices[0:number_of_features]
features=X[:,index]
feature_num=features.shape[1]

GCN_all_accs_one_fetur  = []
GCN_all_scores_one_fetur = []
GCN_all_f1s_one_fetur = []
base_labels=[]

###############################################################################
###############################################################################
#This part is from the NIPS code, generating training, validation and traing set

for runs in range(1):        
    print("\n RUN: {} {} \n".format(runs, sep))

    GCN_accuracies = []
    GCN_scores = []
    strat_labels = []
    GCN_f1s=[]
    
    
    bin_ixs = []
    train_ixs = []

    t=time.process_time()
    skf = StratifiedKFold(n_splits=10, shuffle=True,random_state=int(t))
                          
    for train_index, test_index in skf.split(features, y):
        bin_ixs.append(test_index)    
    
    
        
    for i in range(skf.get_n_splits(features, y)): 
        bins=list(range(skf.get_n_splits(features,y)))
        print("\n Fold: {} {} \n".format(i, sep))
            
        train_data = np.empty([0,features.shape[1]])
        train_labels = [] 
        val_ix = i
        if val_ix == max(bins):
            test_ix = 0
            bins.remove(val_ix)
            bins.remove(test_ix)

        else:
            test_ix = val_ix + 1
            bins.remove(test_ix)
            bins.remove(val_ix)

        val_data, val_labels = features[bin_ixs[val_ix]], y[bin_ixs[val_ix]]
        test_data, test_labels = features[bin_ixs[test_ix]], y[bin_ixs[test_ix]]
        
        for b in bins:
            train_data = np.concatenate((train_data, features[bin_ixs[b]]))
            train_labels = np.concatenate((train_labels, y[bin_ixs[b]]))

###################################################
#Chenxiao: generating permuational matrix
        dist, idx = graph.distance_scipy_spatial(train_data.transpose(), k=10, metric='euclidean')
        A = graph.adjacency(dist, idx).astype(np.float32)

        assert A.shape == (features.shape[1], features.shape[1])
        print('d = |V| = {}, k|V| < |E| = {}'.format(features.shape[1], A.nnz))
        plt.spy(A, markersize=2, color='black')     
        
        graphs, perm = coarsening.coarsen(A, levels=6, self_connections=False)
        
        train_data = coarsening.perm_data(train_data, perm)
        val_data = coarsening.perm_data(val_data, perm)
        test_data = coarsening.perm_data(test_data, perm)

        L = [graph.laplacian(A, normalized=True) for A in graphs]
 #       graph.plot_spectrum(L)    
 ###################################################        
    
        name = 'CGCNN'
        params = common.copy()
        params['dir_name'] = params['dir_name'] + name + '_Run' + str(runs) + '_Skf' + str(i)             
        params['decay_steps'] = len(train_labels) / common['batch_size']
        
        print('begin working!!!!!!!!')
        model_perf.test(models.cgcnn(L, **params), name, params, 
                        train_data, train_labels, val_data, val_labels, test_data, test_labels, val_ix)
        
        scores, f1, y_labels, test_accuracy = model_perf.show()   
            
        strat_labels=np.append(strat_labels, test_labels)
            
####################################################   
#Chenxiao: add Yun's code for logistric regression and SVM, for comparision with GCN case by case
        logistic = linear_model.LogisticRegression(C=1e5)
        rbf = svm.SVC(C=10,kernel='linear',gamma=0.01)
#######################
#logistic regression:

        log=logistic.fit(train_data, train_labels)
    
        #log_prob_val=log.decision_function(val_data)
        #log_prob_test=log.decision_funtion(test_data)
        
        log_acc_val=log.score(val_data, val_labels)
        log_acc_test=log.score(test_data, test_labels)    
        
        ##f1 calculation
        y_pred_val=logistic.predict(val_data)
        y_pred_test=logistic.predict(test_data)
        
        log_f1_val=f1_score(val_labels, y_pred_val)
        log_f1_test=f1_score(test_labels, y_pred_test)
        
        
        print('Logistic Regression Accuracy for Validation: %f' % log_acc_val)
        print('Logistic Regression Accuracy for Test: %f' % log_acc_test)
        print('Logistic Regression F1 for Validation: %f' % log_f1_val)
        print('Logistic Regression F1 for Test: %f' % log_f1_test)
        
        
#SVM:
        rbf=rbf.fit(train_data, train_labels)
    
        #svm_prob_val=rbf.decision_function(val_data)
        #svm_prob_test=rbf.decision_funtion(test_data)
        
        svm_acc_val=rbf.score(val_data, val_labels)
        svm_acc_test=rbf.score(test_data, test_labels)    
        
        #f1 calculation
        y_pred_val=rbf.predict(val_data)
        y_pred_test=rbf.predict(test_data)
        
        svm_f1_val=f1_score(val_labels, y_pred_val)
        svm_f1_test=f1_score(test_labels, y_pred_test)
               
        print('SVM Accuracy for Validation: %f' % svm_acc_val)
        print('SVM Accuracy for Test: %f' % svm_acc_test)
        print('SVM F1 for Validation: %f' % svm_f1_val)
        print('SVM F1 for Test: %f' % svm_f1_test)        
                
####################################################        
        
        
        ##f1 calculation
        #log_f1=f1_score(test_labels, y_labels)            

        GCN_accuracies = np.append(GCN_accuracies, test_accuracy)
        GCN_scores=np.append(GCN_scores, scores)
        GCN_f1s=np.append(GCN_f1s, f1)
   
    base_labels=np.append(base_labels, strat_labels)        
    GCN_all_scores_one_fetur=np.append(GCN_all_scores_one_fetur, GCN_scores) 
    GCN_all_accs_one_fetur=np.append(GCN_all_accs_one_fetur, np.mean(GCN_accuracies))
    GCN_all_f1s_one_fetur =np.append(GCN_all_f1s_one_fetur, np.mean(GCN_f1s))
# Out:
#  RUN: 0 ****************************************************************************************************
#
#
#  Fold: 0 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16716
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8358 edges
# Layer 1: M_1 = |V| = 544 nodes (27 added),|E| = 5573 edges
# Layer 2: M_2 = |V| = 272 nodes (11 added),|E| = 3629 edges
# Layer 3: M_3 = |V| = 136 nodes (5 added),|E| = 2017 edges
# Layer 4: M_4 = |V| = 68 nodes (2 added),|E| = 991 edges
# Layer 5: M_5 = |V| = 34 nodes (1 added),|E| = 378 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 121 edges
# begin working!!!!!!!!
# validation accuracy: peak = 81.82, mean = 79.55
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf0/model-114
# train accuracy: 100.00 (76 / 76), f1 : 100.00, loss: 1.24e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf0/model-114
# test  accuracy: 90.91 (10 / 11), f1 : 93.33, loss: 3.78e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.818182
# Logistic Regression Accuracy for Test: 0.909091
# Logistic Regression F1 for Validation: 0.833333
# Logistic Regression F1 for Test: 0.923077
# SVM Accuracy for Validation: 0.909091
# SVM Accuracy for Test: 1.000000
# SVM F1 for Validation: 0.923077
# SVM F1 for Test: 1.000000
#
#  Fold: 1 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16762
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8381 edges
# Layer 1: M_1 = |V| = 544 nodes (24 added),|E| = 5661 edges
# Layer 2: M_2 = |V| = 272 nodes (9 added),|E| = 3685 edges
# Layer 3: M_3 = |V| = 136 nodes (3 added),|E| = 2108 edges
# Layer 4: M_4 = |V| = 68 nodes (1 added),|E| = 1071 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 439 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 132 edges
# begin working!!!!!!!!
# validation accuracy: peak = 90.91, mean = 75.00
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf1/model-115
# train accuracy: 100.00 (77 / 77), f1 : 100.00, loss: 1.23e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf1/model-115
# test  accuracy: 100.00 (10 / 10), f1 : 100.00, loss: 1.19e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.818182
# Logistic Regression Accuracy for Test: 0.900000
# Logistic Regression F1 for Validation: 0.833333
# Logistic Regression F1 for Test: 0.909091
# SVM Accuracy for Validation: 1.000000
# SVM Accuracy for Test: 1.000000
# SVM F1 for Validation: 1.000000
# SVM F1 for Test: 1.000000
#
#  Fold: 2 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16816
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8408 edges
# Layer 1: M_1 = |V| = 544 nodes (24 added),|E| = 5634 edges
# Layer 2: M_2 = |V| = 272 nodes (10 added),|E| = 3608 edges
# Layer 3: M_3 = |V| = 136 nodes (3 added),|E| = 2087 edges
# Layer 4: M_4 = |V| = 68 nodes (1 added),|E| = 1022 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 410 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 128 edges
# begin working!!!!!!!!
# validation accuracy: peak = 100.00, mean = 87.50
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf2/model-117
# train accuracy: 100.00 (78 / 78), f1 : 100.00, loss: 1.21e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf2/model-117
# test  accuracy: 90.00 (9 / 10), f1 : 92.31, loss: 1.41e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.800000
# Logistic Regression Accuracy for Test: 0.800000
# Logistic Regression F1 for Validation: 0.800000
# Logistic Regression F1 for Test: 0.833333
# SVM Accuracy for Validation: 1.000000
# SVM Accuracy for Test: 0.900000
# SVM F1 for Validation: 1.000000
# SVM F1 for Test: 0.923077
#
#  Fold: 3 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16838
# Layer 0: M_0 = |V| = 1152 nodes (152 added),|E| = 8419 edges
# Layer 1: M_1 = |V| = 576 nodes (49 added),|E| = 5682 edges
# Layer 2: M_2 = |V| = 288 nodes (21 added),|E| = 3730 edges
# Layer 3: M_3 = |V| = 144 nodes (10 added),|E| = 2195 edges
# Layer 4: M_4 = |V| = 72 nodes (5 added),|E| = 1056 edges
# Layer 5: M_5 = |V| = 36 nodes (2 added),|E| = 421 edges
# Layer 6: M_6 = |V| = 18 nodes (0 added),|E| = 139 edges
# begin working!!!!!!!!
# validation accuracy: peak = 90.00, mean = 85.00
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf3/model-117
# train accuracy: 100.00 (78 / 78), f1 : 100.00, loss: 1.28e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf3/model-117
# test  accuracy: 90.00 (9 / 10), f1 : 90.91, loss: 1.64e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.800000
# Logistic Regression Accuracy for Test: 0.800000
# Logistic Regression F1 for Validation: 0.833333
# Logistic Regression F1 for Test: 0.800000
# SVM Accuracy for Validation: 0.900000
# SVM Accuracy for Test: 0.900000
# SVM F1 for Validation: 0.923077
# SVM F1 for Test: 0.909091
#
#  Fold: 4 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16820
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8410 edges
# Layer 1: M_1 = |V| = 544 nodes (22 added),|E| = 5654 edges
# Layer 2: M_2 = |V| = 272 nodes (8 added),|E| = 3668 edges
# Layer 3: M_3 = |V| = 136 nodes (4 added),|E| = 2047 edges
# Layer 4: M_4 = |V| = 68 nodes (1 added),|E| = 1021 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 415 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 126 edges
# begin working!!!!!!!!
# validation accuracy: peak = 70.00, mean = 63.75
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf4/model-117
# train accuracy: 100.00 (78 / 78), f1 : 100.00, loss: 1.19e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf4/model-117
# test  accuracy: 90.00 (9 / 10), f1 : 92.31, loss: 1.69e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.800000
# Logistic Regression Accuracy for Test: 0.900000
# Logistic Regression F1 for Validation: 0.800000
# Logistic Regression F1 for Test: 0.909091
# SVM Accuracy for Validation: 0.900000
# SVM Accuracy for Test: 1.000000
# SVM F1 for Validation: 0.909091
# SVM F1 for Test: 1.000000
#
#  Fold: 5 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16752
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8376 edges
# Layer 1: M_1 = |V| = 544 nodes (23 added),|E| = 5619 edges
# Layer 2: M_2 = |V| = 272 nodes (8 added),|E| = 3645 edges
# Layer 3: M_3 = |V| = 136 nodes (2 added),|E| = 2101 edges
# Layer 4: M_4 = |V| = 68 nodes (1 added),|E| = 1056 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 419 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 124 edges
# begin working!!!!!!!!
# validation accuracy: peak = 90.00, mean = 82.50
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf5/model-118
# train accuracy: 100.00 (79 / 79), f1 : 100.00, loss: 1.13e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf5/model-118
# test  accuracy: 88.89 (8 / 9), f1 : 90.91, loss: 1.67e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 1.000000
# Logistic Regression Accuracy for Test: 0.666667
# Logistic Regression F1 for Validation: 1.000000
# Logistic Regression F1 for Test: 0.666667
# SVM Accuracy for Validation: 1.000000
# SVM Accuracy for Test: 0.888889
# SVM F1 for Validation: 1.000000
# SVM F1 for Test: 0.909091
#
#  Fold: 6 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16610
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8305 edges
# Layer 1: M_1 = |V| = 544 nodes (21 added),|E| = 5563 edges
# Layer 2: M_2 = |V| = 272 nodes (8 added),|E| = 3603 edges
# Layer 3: M_3 = |V| = 136 nodes (2 added),|E| = 2143 edges
# Layer 4: M_4 = |V| = 68 nodes (0 added),|E| = 1090 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 426 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 131 edges
# begin working!!!!!!!!
# validation accuracy: peak = 77.78, mean = 70.83
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf6/model-120
# train accuracy: 100.00 (80 / 80), f1 : 100.00, loss: 1.10e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf6/model-120
# test  accuracy: 100.00 (9 / 9), f1 : 100.00, loss: 1.41e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.666667
# Logistic Regression Accuracy for Test: 0.777778
# Logistic Regression F1 for Validation: 0.666667
# Logistic Regression F1 for Test: 0.800000
# SVM Accuracy for Validation: 0.888889
# SVM Accuracy for Test: 1.000000
# SVM F1 for Validation: 0.909091
# SVM F1 for Test: 1.000000
#
#  Fold: 7 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16574
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8287 edges
# Layer 1: M_1 = |V| = 544 nodes (23 added),|E| = 5483 edges
# Layer 2: M_2 = |V| = 272 nodes (10 added),|E| = 3526 edges
# Layer 3: M_3 = |V| = 136 nodes (4 added),|E| = 2014 edges
# Layer 4: M_4 = |V| = 68 nodes (1 added),|E| = 1010 edges
# Layer 5: M_5 = |V| = 34 nodes (0 added),|E| = 404 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 125 edges
# begin working!!!!!!!!
# validation accuracy: peak = 100.00, mean = 84.72
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf7/model-120
# train accuracy: 98.75 (79 / 80), f1 : 98.99, loss: 1.10e+00
# time: 7s (wall 4s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf7/model-120
# test  accuracy: 66.67 (6 / 9), f1 : 72.73, loss: 2.79e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.888889
# Logistic Regression Accuracy for Test: 0.777778
# Logistic Regression F1 for Validation: 0.909091
# Logistic Regression F1 for Test: 0.800000
# SVM Accuracy for Validation: 1.000000
# SVM Accuracy for Test: 0.777778
# SVM F1 for Validation: 1.000000
# SVM F1 for Test: 0.800000
#
#  Fold: 8 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16670
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8335 edges
# Layer 1: M_1 = |V| = 544 nodes (25 added),|E| = 5590 edges
# Layer 2: M_2 = |V| = 272 nodes (11 added),|E| = 3604 edges
# Layer 3: M_3 = |V| = 136 nodes (4 added),|E| = 2094 edges
# Layer 4: M_4 = |V| = 68 nodes (2 added),|E| = 1017 edges
# Layer 5: M_5 = |V| = 34 nodes (1 added),|E| = 401 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 122 edges
# begin working!!!!!!!!
# validation accuracy: peak = 77.78, mean = 73.61
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf8/model-120
# train accuracy: 100.00 (80 / 80), f1 : 100.00, loss: 1.08e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf8/model-120
# test  accuracy: 100.00 (9 / 9), f1 : 100.00, loss: 1.41e+00
# time: 2s (wall 1s)
# Logistic Regression Accuracy for Validation: 0.777778
# Logistic Regression Accuracy for Test: 1.000000
# Logistic Regression F1 for Validation: 0.800000
# Logistic Regression F1 for Test: 1.000000
# SVM Accuracy for Validation: 0.888889
# SVM Accuracy for Test: 1.000000
# SVM F1 for Validation: 0.909091
# SVM F1 for Test: 1.000000
#
#  Fold: 9 ****************************************************************************************************
#
# d = |V| = 1000, k|V| < |E| = 16714
# Layer 0: M_0 = |V| = 1088 nodes (88 added),|E| = 8357 edges
# Layer 1: M_1 = |V| = 544 nodes (26 added),|E| = 5617 edges
# Layer 2: M_2 = |V| = 272 nodes (11 added),|E| = 3560 edges
# Layer 3: M_3 = |V| = 136 nodes (5 added),|E| = 2018 edges
# Layer 4: M_4 = |V| = 68 nodes (2 added),|E| = 982 edges
# Layer 5: M_5 = |V| = 34 nodes (1 added),|E| = 390 edges
# Layer 6: M_6 = |V| = 17 nodes (0 added),|E| = 129 edges
# begin working!!!!!!!!
# validation accuracy: peak = 100.00, mean = 90.28
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf9/model-117
# train accuracy: 100.00 (78 / 78), f1 : 100.00, loss: 1.21e+00
# time: 7s (wall 3s)
# INFO:tensorflow:Restoring parameters from /Users/ChenxiaoXu/repos/project1/idp_jio/lib/../checkpoints/Chenxiao_TestingCGCNN_Run0_Skf9/model-117
# test  accuracy: 72.73 (8 / 11), f1 : 76.92, loss: 4.79e+00
# time: 3s (wall 2s)
# Logistic Regression Accuracy for Validation: 1.000000
# Logistic Regression Accuracy for Test: 0.818182
# Logistic Regression F1 for Validation: 1.000000
# Logistic Regression F1 for Test: 0.833333
# SVM Accuracy for Validation: 1.000000
# SVM Accuracy for Test: 0.818182
# SVM F1 for Validation: 1.000000
# SVM F1 for Test: 0.857143

# %%
print("Runs Avg Accuracies: {}".format(np.mean(GCN_all_accs_one_fetur)))
print("Standard Deviation: {}".format(np.std(GCN_all_accs_one_fetur)))
print("Runs Avg F1: {}".format(np.mean(GCN_all_f1s_one_fetur)))
print("Standard Deviation: {}".format(np.std(GCN_all_f1s_one_fetur)))
# Out:
# Runs Avg Accuracies: 88.91919191919192
# Standard Deviation: 0.0
# Runs Avg F1: 90.94172494172493
# Standard Deviation: 0.0
